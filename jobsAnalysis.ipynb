# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas, numpy, and matplotlib.

# %%
# Importing the necessary libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations
import matplotlib.pyplot as plt  # For data visualization

# %% [markdown]
# # Load the Dataset
# Use pandas to load the jobs.csv file from the data folder.

# %%
# Load the dataset
# Define the path to the csv file
file_path = 'data/jobs.csv'

# Use pandas to read the csv file
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe to confirm successful loading
df.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0      0                                       Data Analyst
# 1           1      1  Junior Data Analyst/Scientist Role - Contract ...
# 2           2      2                                       Data Analyst
# 3           3      3                                       Data Analyst
# 4           4      4                                       Data Analyst
#
#        company_name                location               via  \
# 0           Chloeta    Oklahoma City, OK     via ZipRecruiter
# 1            Upwork               Anywhere         via Upwork
# 2               ATC        United States         via LinkedIn
# 3        Guidehouse           Topeka, KS            via Nexxt
# 4  AnMed Health LLC               Anywhere       via LinkedIn
#
#                                          description  \
# 0  Job Summary: The Data Analyst oversees data pr...
# ...

# %% [markdown]
# # Inspect the Dataset
# Use methods like head(), info(), and describe() to inspect various aspects of the dataset.

# %%
# Inspect the Dataset

# Use the head() function to get the first 5 rows of the dataframe
df.head()

# Use the info() function to get a concise summary of the dataframe
df.info()

# Use the describe() function to generate descriptive statistics of the dataframe
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41491 entries, 0 to 41490
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           41491 non-null  int64
#  1   index                41491 non-null  int64
#  2   title                41491 non-null  object
#  3   company_name         41491 non-null  object
#  4   location             41462 non-null  object
#  5   via                  41482 non-null  object
#  6   description          41491 non-null  object
#  7   extensions           41491 non-null  object
#  8   job_id               41491 non-null  object
#  9   thumbnail            24498 non-null  object
#  10  posted_at            41491 non-null  object
#  11  schedule_type        41314 non-null  object
#  12  work_from_home       18697 non-null  object
#  13  salary               7091 non-null   object
#  14  search_term          41491 non-null  object
# ...

# %% [markdown]
# # Data Cleaning
# Identify and handle missing values, outliers, and any other inconsistencies in the dataset.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)

# Fill missing values with appropriate method
# Here we are using forward fill method as an example
df.fillna(method='ffill', inplace=True)

# Check for outliers using Z-score method
from scipy import stats
z_scores = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
outliers = (z_scores > 3).any(axis=1)  # Here 3 is the threshold, adjust it according to your needs
df_outliers = df[outliers]

# Handle outliers
# Here we are removing the outliers as an example
df = df[~outliers]

# Check for any inconsistencies in the data
# Here we are checking for any duplicate rows
duplicates = df.duplicated()
print("Number of duplicate rows = ", duplicates.sum())

# Handle duplicates
# Here we are removing the duplicates
df = df[~duplicates]
# Out:
# Missing values in each column:
#  Unnamed: 0                 0
# index                      0
# title                      0
# company_name               0
# location                   0
# via                        0
# description                0
# extensions                 0
# job_id                     0
# thumbnail                  2
# posted_at                  0
# schedule_type              0
# work_from_home             1
# salary                    13
# search_term                0
# date_time                  0
# search_location            0
# commute_time           41491
# salary_pay                13
# salary_rate               13
# salary_avg                13
# salary_min                13
# salary_max                13
# salary_hourly             13
# salary_yearly             98
# salary_standardized       13
# description_tokens         0
# dtype: int64
# ...

# %% [markdown]
# # Data Visualization
# Use matplotlib and seaborn to create visualizations that help understand the distribution, correlation, and other relationships in the data.

# %%
import pandas as pd

# Load the data
df = pd.read_csv('data/jobs.csv')

# Counting the frequency of each job title in the dataset
job_titles = df['title'].value_counts().head(10)

# Plotting the bar chart
plt.figure(figsize=(10,5))

# Create the bar chart
job_titles.plot(kind='bar')

# Set the title and labels
plt.title('Top 10 Most Frequent Job Titles')

# Show the plot
plt.show()
